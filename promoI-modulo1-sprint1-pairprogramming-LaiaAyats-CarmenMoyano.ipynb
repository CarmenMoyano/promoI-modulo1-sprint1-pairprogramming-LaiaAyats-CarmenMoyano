# %% [markdown]
# Cread tres variables numéricas de tipo integer (entero), llamadas de la siguiente forma:
#
#     numero1
#
#     numero2
#
#     numero3
# Utilizando los operadores lógicos:
#
#     En vuestro caso, es el numero1 mayor que el numero2
#
#     Es el numero1 menor que el numero2 pero mayor que el numero3
#
#     Es el numero3 igual que el numero2
#
#     Es el numero2 distinto que el numero1

# %%
numero1 = 24
numero2 = 7
numero3 = 12
print("¿Es el numero 1 mayor que el numero 2?", numero1 > numero2)
print("¿Es el numero 1 menor que el numero 2 pero mayor que el numero 3?", numero3 < numero1 < numero2)
print("¿Es el numero 3 igual que el numero 2?", numero3 == numero2)
print("¿Es el numero 2 distinto que el numero 1?", numero2 != numero1)
# Out:
# ¿Es el numero 1 mayor que el numero 2? True
# ¿Es el numero 1 menor que el numero 2 pero mayor que el numero 3? False
# ¿Es el numero 3 igual que el numero 2? False
# ¿Es el numero 2 distinto que el numero 1? True

# %% [markdown]
# Cread dos variables numéricas de tipo float (decimal) con dos decimales, llamdas de la siguiente forma:
#
#     altura1
#
#     altura2
#
# Utilizando los operadores matemáticos aprendidos en la lección:
#
#     Cuál es la suma de las dos alturas
#
#     Cuál es la diferencia entre las alturas
#
#     Cuál es el resto de la división de las dos alturas
#
#     Cuál es resultado de la división de las dos alturas, redondead el resultado a un decimal.

# %%
altura1 = 1.70
altura2 = 1.65
print("¿Cuál es la suma de las dos alturas?", altura1 + altura2)
print("¿Cuál es la diferencia entre las alturas?", altura1 - altura2)
print("¿Cuál es el resto de la división de las dos alturas?", altura1 % altura2)
division_alturas = altura1 / altura2
print("¿Cuál es resultado de la división de las dos alturas (1 decimal)?", round(division_alturas,1))
# Out:
# ¿Cuál es la suma de las dos alturas? 3.3499999999999996
# ¿Cuál es la diferencia entre las alturas? 0.050000000000000044
# ¿Cuál es el resto de la división de las dos alturas? 0.050000000000000044
# ¿Cuál es resultado de la división de las dos alturas (1 decimal)? 1.0

# %% [markdown]
# Escribid un programa usando la función input() que le pregunte al usuario su nombre y apellidos. Una vez que tengamos el nombre del usuario:
#
#     Printead su nombre y apellidos todo en mayúsculas
#
#     Printead su nombre y apellidos todo en minúsculas
#
#     Printead su nombre y apellidos con la primera letra del nombre y los apellidos en mayúscula y el resto en minúscula.
#
#     Printeas solo la primera letra del nombre en mayúscula.

# %%
nombre_apellido = input ("Escribe tu nombre y apellidos")
print("nombre y apellidos todo en mayúsculas:", nombre_apellido.upper())
print("nombre y apellidos todo en minúsculas:", nombre_apellido.lower())
print("nombre y apellidos con la primera letra del nombre y los apellidos en mayúscula y el resto en minúscula:", nombre_apellido.title())
print("solo la primera letra del nombre en mayúscula:", nombre_apellido.capitalize())
# Out:
# nombre y apellidos todo en mayúsculas: MANOLITA MARTINEZ LÓPEZ
# nombre y apellidos todo en minúsculas: manolita martinez lópez
# nombre y apellidos con la primera letra del nombre y los apellidos en mayúscula y el resto en minúscula: Manolita Martinez López
# solo la primera letra del nombre en mayúscula: Manolita martinez lópez

# %% [markdown]
# Escribid un programa usando la función input() que:
#
#     Le pregunte al usuario por una frase, almacenad este resultado en una variable.
#
#     Le pregunte al usuario por una vocal, almacenad este resultado en una variable.
#
#     Printead la misma frase pero con la vocal introducida en mayúsulas.

# %%
frase = input ("¿Como te llamas?")
vocal = input ("Introduce una vocal")
vocal_mayucula = vocal.upper()
frase_con_vocal_mayuscula = frase.replace(vocal, vocal_mayucula)
print ("El nombre es:", frase, "\nla vocal es:", vocal, "\nahora la tu nombre se muestra:", frase_con_vocal_mayuscula)
# Out:
# El nombre es: manolita
# la vocal es: a
# ahora la tu nombre se muestra: mAnolitA

# %% [markdown]
# Escribid un programa usando la función input() que:
#
#     Le pregunte al usuario por la lista de la compra, separando cada elemento por comas.
#
#     Devolved la lista de compra donde veamos cada elemento en una línea

# %%
lista_compra = input("introduce la lista de tú compra")
print(lista_compra)
string_lista = "\n".join(lista_compra.split(", "))
print(string_lista)
# Out:
# manzanas, peras
# manzanas
# peras
